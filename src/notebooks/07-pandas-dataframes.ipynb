# %% [markdown]
# # Pandas Dataframes

# %%
import numpy as np
import pandas as pd

# %%
from numpy.random import randn

# %%
np.random.seed(101)

# %%
df = pd.DataFrame(randn(5,4),['A','B','C','D','E'],['W','X','Y','Z'])
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
print(df['X'])
print(type(df['X']))
# Out:
# A    0.628133
# B   -0.319318
# C    0.740122
# D   -0.758872
# E    1.978757
# Name: X, dtype: float64
# <class 'pandas.core.series.Series'>

# %%
df.Y
# Out:
# A    0.907969
# B   -0.848077
# C    0.528813
# D   -0.933237
# E    2.605967
# Name: Y, dtype: float64

# %%
df[['W','Z']]
# Out:
#           W         Z
# A  2.706850  0.503826
# B  0.651118  0.605965
# C -2.018168 -0.589001
# D  0.188695  0.955057
# E  0.190794  0.683509

# %%
df['new'] = df['Y'] + df['W']
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
df.drop('X',axis=1)
# Out:
#           W         Y         Z       new
# A  2.706850  0.907969  0.503826  3.614819
# B  0.651118 -0.848077  0.605965 -0.196959
# C -2.018168  0.528813 -0.589001 -1.489355
# D  0.188695 -0.933237  0.955057 -0.744542
# E  0.190794  2.605967  0.683509  2.796762

# %%
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
df.drop('X',axis=1,inplace=True)

# %%
df
# Out:
#           W         Y         Z       new
# A  2.706850  0.907969  0.503826  3.614819
# B  0.651118 -0.848077  0.605965 -0.196959
# C -2.018168  0.528813 -0.589001 -1.489355
# D  0.188695 -0.933237  0.955057 -0.744542
# E  0.190794  2.605967  0.683509  2.796762

# %%
df.loc[['A','B']]
# Out:
#           W         Y         Z       new
# A  2.706850  0.907969  0.503826  3.614819
# B  0.651118 -0.848077  0.605965 -0.196959

# %%
df.iloc[[0,2]]
# Out:
#           W         Y         Z       new
# A  2.706850  0.907969  0.503826  3.614819
# C -2.018168  0.528813 -0.589001 -1.489355

# %%
df.loc['A','W']
# Out:
# 2.706849839399938

# %%
df > 0
# Out:
#        W      Y      Z    new
# A   True   True   True   True
# B   True  False   True  False
# C  False   True  False  False
# D   True  False   True  False
# E   True   True   True   True

# %%
df[df > 0].fillna(0)
# Out:
#           W         Y         Z       new
# A  2.706850  0.907969  0.503826  3.614819
# B  0.651118  0.000000  0.605965  0.000000
# C  0.000000  0.528813  0.000000  0.000000
# D  0.188695  0.000000  0.955057  0.000000
# E  0.190794  2.605967  0.683509  2.796762

# %%
df > 0
# Out:
#        W      Y      Z    new
# A   True   True   True   True
# B   True  False   True  False
# C  False   True  False  False
# D   True  False   True  False
# E   True   True   True   True

# %%
df[df['W'] > 0]
# Out:
#           W         Y         Z       new
# A  2.706850  0.907969  0.503826  3.614819
# B  0.651118 -0.848077  0.605965 -0.196959
# D  0.188695 -0.933237  0.955057 -0.744542
# E  0.190794  2.605967  0.683509  2.796762

# %%
df.reset_index(inplace=False)
# Out:
#   index         W         Y         Z       new
# 0     A  2.706850  0.907969  0.503826  3.614819
# 1     B  0.651118 -0.848077  0.605965 -0.196959
# 2     C -2.018168  0.528813 -0.589001 -1.489355
# 3     D  0.188695 -0.933237  0.955057 -0.744542
# 4     E  0.190794  2.605967  0.683509  2.796762

# %%
df[(df['Z'] > 0) & (df['W'] > 1)]
# Out:
#          W         Y         Z       new
# A  2.70685  0.907969  0.503826  3.614819

# %%
newind = 'CA NY WY OR CO'.split(" ")
newind
df["States"] = newind
df
# Out:
#           W         Y         Z       new States
# A  2.706850  0.907969  0.503826  3.614819     CA
# B  0.651118 -0.848077  0.605965 -0.196959     NY
# C -2.018168  0.528813 -0.589001 -1.489355     WY
# D  0.188695 -0.933237  0.955057 -0.744542     OR
# E  0.190794  2.605967  0.683509  2.796762     CO

# %%
df.set_index('States')
# Out:
#                W         Y         Z       new
# States
# CA      2.706850  0.907969  0.503826  3.614819
# NY      0.651118 -0.848077  0.605965 -0.196959
# WY     -2.018168  0.528813 -0.589001 -1.489355
# OR      0.188695 -0.933237  0.955057 -0.744542
# CO      0.190794  2.605967  0.683509  2.796762
